# %% [markdown]
# # Results

# %%
from generate import generate_unconditionally, generate_conditionally
from utils import plot_stroke, attention_plot

# %% [markdown]
# Please, don't modify anything below.
#
# ### Unconditional generation:

# %%
stroke = generate_unconditionally()
plot_stroke(stroke)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-9151c8275422> in <module>
# ----> 1 stroke = generate_unconditionally()
#       2 plot_stroke(stroke)
#
# ~/Documents/descript-test/generate.py in generate_unconditionally(hidden_size, mix_components, steps, feature_dim, random_state, saved_model)
#      53     # load model and trained weights
#      54     model = HandwritingPrediction(  # 3 is the stroke feature dim
# ---> 55         args.hidden_size, args.mix_components, 3)
#      56     model.load_state_dict(torch.load(saved_model)['model'])
#      57     optimizer = optim.Adam([{'params': model.parameters()}],
#
# NameError: name 'args' is not defined

# %% [markdown]
# ### Conditional generation:

# %%
stroke, phis = generate_conditionally(text='welcome to lyrebird', bias=5)
plot_stroke(stroke)
attention_plot(phis)

# %%
stroke, phis = generate_conditionally(text='how are you?')
plot_stroke(stroke)
attention_plot(phis)
